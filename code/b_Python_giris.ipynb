# %% [markdown]
# # **Python Giriş**
# ![image.png](data:image/png;base64,...)

# %%
print("Merhaba Dünya")
# Out:
# Merhaba Dünya

# %%
3+5 # notebook a özgü ipynb i py  nb interactive Python NoteBook
# Out:
# 8

# %%
print(3+5)
# Out:
# 8

# %% [markdown]
# Colab i tarayıcı açabildiğiniz herhangi bir mobil cihazdan da kullanabilirsiniz.

# %% [markdown]
# [Murat ALTUN Web Sayfası](https://drmurataltun.github.io)

# %%
print("E"+"C"+"S")
# Out:
# ECS

# %%
print("3"+"6"+"9")
# Out:
# 369

# %%
degisken=369
type(degisken)
# Out:
# int

# %%
degisken2="3"+"6"+"9"
type(degisken2)
# Out:
# str

# %%
print(3*3) # int
# Out:
# 9

# %%
print("3"*3) #str
# Out:
# 333

# %%
print(3*"A") #str
# Out:
# AAA

# %%
print("Murat", "Altun", "YZ Eğitmeni")
# Out:
# Murat Altun YZ Eğitmeni

# %%
ad="Murat"
soyad="ALTUN"
yas=44
print(ad,soyad,yas)
# Out:
# Murat ALTUN 44

# %% [markdown]
# # Başlık
# ## Alt Başlık
#
#
# > alıntı bloku
#
# > alıntı bloku

# %%
print(
"""
1. Girdi
2. İşlem
3. Çıktı
"""

)
# Out:
# 1. Girdi
# 2. İşlem
# 3. Çıktı

# %%
print("\n merhaba") #kaçış karakteri
# Out:
#  merhaba

# %%
print("merhaba\t\tarkadaşlar\nnasılsınız\tnaber") #kaçış karakteri
# Out:
# merhaba		arkadaşlar
# nasılsınız	naber

# %%
print("""
🪬🪬🪬🪬
❤️❤️❤️
""")
# Out:
# 🪬🪬🪬🪬
# ❤️❤️❤️

# %%
#Veri Türleri
sayi=1
sayi="Murat"

# %%
sayi
# Out:
# 'Murat'

# %%
sayi1=sayi
sayi=5
print(sayi1)
# Out:
# Murat

# %%
print(sayi)
# Out:
# 5

# %%
tamsayi=5
type(tamsayi)
# Out:
# int

# %%
ond_sayi=5.0
type(ond_sayi)
# Out:
# float

# %%
isim="Murat"
type(isim)
# Out:
# str

# %%
liste=["Murat","Altun",44]
type(liste)
# Out:
# list

# %%
liste[0] #liste sıra numarası 0 dan başlar yani index
# Out:
# 'Murat'

# %%
type(liste[0])
# Out:
# str

# %%
type(liste[2])
# Out:
# int

# %% [markdown]
# liste içinde karışık türden ögeler bulunur.

# %%
#Değişkenler
#Baharat Kutusu
tuzluk="tuz"
print("Tuzluk içinde ne var: ", tuzluk)
#değişken tuzluk içindeki deeğr yani tuz
# Out:
# Tuzluk içinde ne var:  tuz

# %%
tuzluk="karabiber"
print("Tuzluk içinde ne var: ", tuzluk)
#Gibi deki cosplay deki fotoğrafçı sahnesi
# Out:
# Tuzluk içinde ne var:  karabiber

# %% [markdown]
# 1.   Değişkenin adı sayıyla başlayamaz
# 2.   Python tarafından reserve edilmiş, kullanılan özel sözcükler olamaz print="Murat" X
#
# 3.   Değişken adı değerle uyumlu olmalı tuzluk örneği gibi
# 4.   kısa anlamlı değişken adları olmalı, Türkçe destekliyor ancak topluluk desteği ve global çalışma için İngilizce sozcukler seçilmeli,
# 5.   snake yazım kullanırız kimlik_no

# %%
f"MErhaba {1}"
# Out:
# 'MErhaba 1'

# %% [markdown]
# <table>
# <tr>
# <td>
# <strong>
# ad
# </strong>
# </td>
# <td>
# <strong>
# soyad
# </strong>
# </td>
# </tr>
# <tr>
# <td>
# <strong>
# murat
# </strong>
# </td>
# <td>
# <strong>
# altun
# </strong>
# </td>
# </tr>
# </table>

# %%
liste=[["Sena", "Şamlıoğu",4],
       ["Rana","Selim", 4],
       ["Kübra", "Kılıç", 3],
       ["Hakan", "Kıran", 2],
       ["Murat", "Altun",3]
       ]

# %%
liste
# Out:
# [['Sena', 'Şamlıoğu', 4],
#  ['Rana', 'Selim', 4],
#  ['Kübra', 'Kılıç', 3],
#  ['Hakan', 'Kıran', 2],
#  ['Murat', 'Altun', 3]]

# %%
liste[0]
# Out:
# ['Sena', 'Şamlıoğu', 4]

# %%
type(liste[0])
# Out:
# list

# %%
liste[0][2]
# Out:
# 4

# %%
type(liste[0][2])
# Out:
# int

# %%
type(liste[0][0])
# Out:
# str

# %%
#insan nesnesi
#insanın bazı özlelikleri vardır
#fiziksel özellikleri, kişilik özellikleri
# işlevleri düşünür, konuşur, yürür  metotlar
"""class insan:
    def __init__"""

# %%
#string metotları
metin="Python programlama dili"
print(metin.upper()) #metotlarda parantez olur
print(metin)
# Out:
# PYTHON PROGRAMLAMA DILI
# Python programlama dili

# %%
print(metin.lower()) #hepsi küçük harf
print(metin.title()) #sözcüklerin ilk harfi
print(metin.capitalize()) #baş harfi büyük
# Out:
# python programlama dili
# Python Programlama Dili
# Python programlama dili

# %%
metin.find("Python") #bulunduğu konum index
# Out:
# 0

# %%
metin.find("Murat") #-1 bulunamadığını gösterir
# Out:
# -1

# %%
metin="Murat ve Murat ve"
metin.count("ve") #verilen karakter dizisinin kaç kere tekrarlandığını
# Out:
# 2

# %%
ad=input("Adınız: ")
ad=ad.rstrip()
ad=ad.lstrip()
print(type(ad))
print(ad)
soyad=input("Soyadınız: ")
yas=int(input("Yaşınız: "))
# Out:
# Adınız: Murat
# <class 'str'>
# Murat
# Soyadınız: altun
# Yaşınız: 44

# %%
metin="Ben Java seviyorum."
yeni_metin=metin.replace("Java","Python")
print(yeni_metin)
# Out:
# Ben Python seviyorum.

# %%
isimler="Bora, Tuğrul, İrem,Mehmet"
liste=isimler.split(",")
print(liste)
# Out:
# ['Bora', ' Tuğrul', ' İrem', 'Mehmet']

# %%
metin
# Out:
# 'Ben Java seviyorum.'

# %%
metin.startswith("Ben") #verilen karakter dizisiyle başlıyor mu
# Out:
# True

# %%
metin.endswith("rum.")
# Out:
# True

# %%
metin="123434556" #karakter dizisi rakamlardan mı oluşuyor
metin.isdigit()
# Out:
# True

# %%
metin="TR-123456" #karakter dizisi ... mi başlıyor
metin.startswith("TR-")
# Out:
# True

# %%
metin1="Abvcd6" #karakter dizisi harflerden mi oluşuyor
metin2="Abcde"
print(metin1.isalpha())
print(metin2.isalpha())
# Out:
# False
# True

# %%
"abcd 123".isalnum() # boşluk varsa False
# Out:
# False

# %%
"abcd123".isalnum()
# Out:
# True

# %%
meyve_sepeti=["elma","armut", "ananas"]
meyve_sepeti.append("Muz") # listeye yeni eleman ekler
print(meyve_sepeti)
# Out:
# ['elma', 'armut', 'ananas', 'Muz']

# %%
meyve_sepeti.insert(2,"Kayısı")
meyve_sepeti[2]
# Out:
# 'Kayısı'

# %%
meyve_sepeti2=["Nar","kivi","avakado"]

# %%
#sepetleri birbirine ekle
meyve_sepeti.extend(meyve_sepeti2)
meyve_sepeti
# Out:
# ['elma', 'armut', 'Kayısı', 'ananas', 'Muz', 'Nar', 'kivi', 'avakado']

# %%
meyve_sepeti.remove("kayısı")
print(meyve_sepeti)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2962183168.py in <cell line: 0>()
# ----> 1 meyve_sepeti.remove("kayısı")
#       2 print(meyve_sepeti)
#
# ValueError: list.remove(x): x not in list

# %%
meyve_sepeti.remove("Kayısı")
print(meyve_sepeti)
# Out:
# ['elma', 'armut', 'ananas', 'Muz', 'Nar', 'kivi', 'avakado']

# %%
meyve_sepeti.pop(3)
meyve_sepeti
# Out:
# ['elma', 'armut', 'ananas', 'Nar', 'kivi', 'avakado']

# %%
meyve_sepeti.clear()

# %%
meyve_sepeti
# Out:
# []

# %%
sayilar=[1,3,9,2,4,73,8]
sayilar.sort() #varsayılan küçükten büyüğe
sayilar
# Out:
# [1, 2, 3, 4, 8, 9, 73]

# %%
sayilar.sort(reverse=True) #büyükten küçüğe
sayilar
# Out:
# [73, 9, 8, 4, 3, 2, 1]

# %%
harfler=['a','b','c']
harfler.reverse()
harfler
# Out:
# ['c', 'b', 'a']

# %%
harfler.index("a")
# Out:
# 2

# %%
takimlar=['FB','GS','BJK','FB','FB','GS' ]
takimlar.count("FB")
# Out:
# 3

# %%
"""
Metot	    Ne Yapar?	                Örnek Kullanım
append(x)	    Sona x ekler.	        liste.append(5)
insert(i, x)	i indeksine x ekler.	liste.insert(0, 5)
pop(i)	i indeksini siler ve döndürür.	liste.pop(2)
remove(x)	x değerini siler.	        liste.remove(5)
sort()	        Sıralar.	            liste.sort()
reverse()	    Ters çevirir.	        liste.reverse()
count(x)	    x sayısını verir.	    liste.count(5)

"""
# Out:
# '\nMetot\t    Ne Yapar?\t                Örnek Kullanım\nappend(x)\t    Sona x ekler.\t        liste.append(5)\ninsert(i, x)\ti indeksine x ekler.\tliste.insert(0, 5)\npop(i)\ti indeksini siler ve döndürür.\tliste.pop(2)\nremove(x)\tx değerini siler.\t        liste.remove(5)\nsort()\t        Sıralar.\t            liste.sort()\nreverse()\t    Ters çevirir.\t        liste.reverse()\ncount(x)\t    x sayısını verir.\t    liste.count(5)\n\n'

# %%
#dilimleme
meyve_sepeti=["elma","armut", "kayısı", "muz" ]
meyve_sepeti[:3]
# Out:
# ['elma', 'armut', 'kayısı']

# %%
meyve_sepeti[-1]
# Out:
# 'muz'

# %%
meyve_sepeti[0]
# Out:
# 'elma'

# %%
for meyve in meyve_sepeti:
  print(meyve)
# Out:
# elma
# armut
# kayısı
# muz

# %%
toplam=0
for sayi in range(1,100):
    toplam=toplam+sayi
print(toplam)
# Out:
# 4950

# %%
meyve_sepeti[::-1] # listeyi tersten alır başlangıç , bitiş ve adım sayısı
# Out:
# ['muz', 'kayısı', 'armut', 'elma']

# %%
meyve_sepeti[:]
# Out:
# ['elma', 'armut', 'kayısı', 'muz']

# %%
print(*range(0,100,3))
# Out:
# 0 3 6 9 12 15 18 21 24 27 30 33 36 39 42 45 48 51 54 57 60 63 66 69 72 75 78 81 84 87 90 93 96 99

# %%
arac={"marka":"Toyota",
          "yil":2015}

arac.get("marka")
# Out:
# 'Toyota'

# %%
ogrenciler={101:{"ad":"Ali",
                 "soyad":"Kurt",
                 "bolum_kodu":204,
                 "notlar":[70,80,90]
                 },

            102:{"ad":"Ahmet",
                 "soyad":"Yılmaz",
                 "bolum_kodu":204,
                 "notlar":[70,80,90]
                }
            }

# %%
ogrenciler.get(101)
# Out:
# {'ad': 'Ali', 'soyad': 'Kurt', 'bolum_kodu': 204, 'notlar': [70, 80, 90]}

# %%
ogrenci_101=ogrenciler.get(101)
type(ogrenci_101)
# Out:
# dict

# %%
ogrenci_101.get("ad")
# Out:
# 'Ali'

# %%
ogrenci_101.get("notlar")
# Out:
# [70, 80, 90]

# %%
pip install pandas

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.2
